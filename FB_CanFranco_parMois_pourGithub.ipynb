# %%
import glob, os, numpy
import pandas as pan

# %%
tousfich = glob.glob(os.path.join("", "FB*.csv"))
print(tousfich)
# Out:
# ['FB_Canada_Franco_2022-08.csv', 'FB_Canada_Franco_2022-09.csv', 'FB_Canada_Franco_2021-12.csv', 'FB_Canada_Franco_2021-06.csv', 'FB_Canada_Franco_2023-03.csv', 'FB_Canada_Franco_2023-02.csv', 'FB_Canada_Franco_2021-07.csv', 'FB_Canada_Franco_2021-05.csv', 'FB_Canada_Franco_2021-11.csv', 'FB_Canada_Franco_2023-01.csv', 'FB_Canada_Franco_2021-10.csv', 'FB_Canada_Franco_2021-04.csv', 'FB_Canada_Franco_2023-05.csv', 'FB_Canada_Franco_2023-04.csv', 'FB_Canada_Franco_2021-01.csv', 'FB_Canada_Franco_2021-03.csv', 'FB_Canada_Franco_2021-02.csv', 'FB_Canada_Franco_2021-09.csv', 'FB_Canada_Franco_2021-08.csv', 'FB_Canada_Franco_2022-01.csv', 'FB_Canada_Franco_2022-02.csv', 'FB_Canada_Franco_2022-03.csv', 'FB_Canada_Franco_2022-07.csv', 'FB_Canada_Franco_2022-06.csv', 'FB_Canada_Franco_2022-12.csv', 'FB_Canada_Franco_2022-04.csv', 'FB_Canada_Franco_2022-10.csv', 'FB_Canada_Franco_2022-11.csv', 'FB_Canada_Franco_2022-05.csv']

# %%
chq_fich = (pan.read_csv(f, low_memory=False) for f in tousfich)

# %%
fich = pan.concat(chq_fich, ignore_index=True)

# %%
fich
# Out:
#                    Page Name              User Name      Facebook Id  \
# 0        Boni Richard Ouorou          Ouorourichard  100044592902599
# 1             Steve Wulfrand         Stevewulfrand0  100083296573498
# 2               Piranha Club           Piranha.Club  100081333356954
# 3                   Bara pro         barakoudalogie  100063863163987
# 4           Moe L'enjailleur  moelenjailleurcomedie  100077936434268
# ...                      ...                    ...              ...
# 8168706     Le Rose Pingouin           RosePingouin  327937210552822
# 8168707          IDRC / CRDI              IDRC.CRDI  100064605017187
# 8168708          IDRC / CRDI              IDRC.CRDI  100064605017187
# 8168709          IDRC / CRDI              IDRC.CRDI  100064605017187
# 8168710          IDRC / CRDI              IDRC.CRDI  100064605017187
#
#                    Page Category Page Admin Top Country  \
# 0                     POLITICIAN                     CA
# ...

# %%
idMedias = [100064629642245,
100064702091893,
100064469930497,
100057677935882,
100064750746253,
100055228675506,
100063641827245,
100063709793429,
100064854125890,
100064851813351,
100063772922658,
131191820259167,
100063546551184,
100063740523358,
100064010050671,
100064833755433,
100064403815260,
100063566864207,
100064823193433,
100063623140529,
423596921055456,
254768477928383,
271036236431606,
128015371297,
196774760345640,
100063980265361,
100064359562713,
100063781831508,
100063546582140,
100064349397262,
100064898493568,
100064435129941,
213820898747207,
211536155525838,
275069289242598,
471020985450,
100064731343439,
100064243942560,
152856822182,
100063474016000,
100050556595710,
100053947105104,
100063495163209,
100046352926785,
100064973430656,
100063589332484,
100064916282950,
100063772441457,
100063655299339,
134483853321456,
100063709022561,
100064911841442,
100052602765113,
100063573488449,
100063511843498,
100063551261544,
100063478334106,
100063649146357,
100045218839045,
100063573396019,
100064414463045,
100063489424900,
100067786043676,
100041318425885,
100064331186546,
100064539768477,
100063079336391,
100046423946097,
100070732694157,
1568411916822268,
468517777286271,
100064955703081,
100058705311861,
107477141151490,
100076581331516,
100064641671677,
100071327771558,
100063547841524,
100063651653741,
100063463361214,
100064480158321,
100040926144946,
100066781795023,
100063457236729,
100050442861803,
100081960135292,
100063634145177,
112385513782846,
100063624337637,
100059981777535,
100064702715241,
100063667715164,
109513637357837,
100038387810839,
100042407152770,
100032450577149,
100071202192678]

# %%
len(idMedias) #ID Facebook
# Out:
# 309

# %%
fich["média"] = fich["Facebook Id"].isin(idMedias)

# %%
fich
# Out:
#                    Page Name              User Name      Facebook Id  \
# 0        Boni Richard Ouorou          Ouorourichard  100044592902599
# 1             Steve Wulfrand         Stevewulfrand0  100083296573498
# 2               Piranha Club           Piranha.Club  100081333356954
# 3                   Bara pro         barakoudalogie  100063863163987
# 4           Moe L'enjailleur  moelenjailleurcomedie  100077936434268
# ...                      ...                    ...              ...
# 8168706     Le Rose Pingouin           RosePingouin  327937210552822
# 8168707          IDRC / CRDI              IDRC.CRDI  100064605017187
# 8168708          IDRC / CRDI              IDRC.CRDI  100064605017187
# 8168709          IDRC / CRDI              IDRC.CRDI  100064605017187
# 8168710          IDRC / CRDI              IDRC.CRDI  100064605017187
#
#                    Page Category Page Admin Top Country  \
# 0                     POLITICIAN                     CA
# ...

# %%
fich.média.value_counts()
# Out:
# False    7141018
# True     1027693
# Name: média, dtype: int64

# %%
medias = fich.média == True

# %%
fich[medias]
# Out:
#                              Page Name      User Name      Facebook Id  \
# 244                         ICI Estrie      iciestrie  211536155525838
# 341             Le Journal de Montréal    jdemontreal  100064702091893
# 478                                RDS            RDS  100064854125890
# 581                     Narcity Québec  NarcityQuebec  271036236431606
# 589                                RDS            RDS  100064854125890
# ...                                ...            ...              ...
# 8168619  L'info du Nord Mont-Tremblant  linfodunordmt  100063565902064
# 8168620  L'info du Nord Mont-Tremblant  linfodunordmt  100063565902064
# 8168621  L'info du Nord Mont-Tremblant  linfodunordmt  100063565902064
# 8168622  L'info du Nord Mont-Tremblant  linfodunordmt  100063565902064
# 8168628                      La Presse     LaPresseFB  100064750746253
#
#                          Page Category Page Admin Top Country  \
# ...

# %%
fich[~medias]
# Out:
#                    Page Name              User Name      Facebook Id  \
# 0        Boni Richard Ouorou          Ouorourichard  100044592902599
# 1             Steve Wulfrand         Stevewulfrand0  100083296573498
# 2               Piranha Club           Piranha.Club  100081333356954
# 3                   Bara pro         barakoudalogie  100063863163987
# 4           Moe L'enjailleur  moelenjailleurcomedie  100077936434268
# ...                      ...                    ...              ...
# 8168706     Le Rose Pingouin           RosePingouin  327937210552822
# 8168707          IDRC / CRDI              IDRC.CRDI  100064605017187
# 8168708          IDRC / CRDI              IDRC.CRDI  100064605017187
# 8168709          IDRC / CRDI              IDRC.CRDI  100064605017187
# 8168710          IDRC / CRDI              IDRC.CRDI  100064605017187
#
#                    Page Category Page Admin Top Country  \
# 0                     POLITICIAN                     CA
# ...

# %%
fich[medias]["Page Name"].value_counts().head(50)
# Out:
# Le Journal de Québec                  37786
# Le Journal de Montréal                36761
# La Voix de l'Est                      35113
# Le Nouvelliste                        33854
# La Presse                             30818
# TVA Nouvelles                         29064
# Le Soleil                             27886
# Le Droit                              25079
# RDS                                   23167
# Le Devoir                             21635
# Le Quotidien                          20891
# La Tribune                            20646
# Radio-Canada Information              20557
# Narcity Québec                        15832
# www.lanouvelle.net                    14702
# Journal Métro                         13462
# Les Affaires                          13414
# ICI Québec                            11127
# EnBeauce.com                          10524
# Journal Le Soir                       10111
# FM 103,3 - La radio allumée            9321
# ...

# %%
fich[~medias]["Page Name"].value_counts().head(50)
# Out:
# Votemeyo                                             60276
# Spotted: Jeunes mamans                               57877
# Drive Good                                           57042
# Hockey30.com                                         23134
# Spotted st-jérome                                    22847
# Truck Stop Quebec                                    20811
# La Ligue des DEALS                                   20797
# Spotted Valleyfield                                  17940
# Boucherie Tendre Gourmet inc                         16942
# Monsieur Deals                                       16810
# Spotted Terrebonne - Mascouche                       15993
# Les p'tits Deals                                     15477
# Ayoye                                                15151
# Grands Titres                                        14864
# QC Lifestyle                                         14858
# Veux-Tu Rire?                                        14857
# ...

# %%
fich["inter"] = fich.Likes + fich.Comments + fich.Shares + fich.Love + fich.Wow + fich.Haha + fich.Sad + fich.Angry + fich.Care

# %%
fich[medias].groupby(by=["Page Name"]).inter.sum().sort_values(ascending=False).head(50)
# Out:
# Page Name
# TVA Nouvelles                         26995850
# Le Journal de Montréal                16742400
# RDS                                   16369283
# Radio-Canada Information              10363908
# Le Journal de Québec                   8348108
# La Presse                              7622784
# Narcity Québec                         7520944
# Le Devoir                              7381130
# TVA Sports                             6216226
# Le Soleil                              3816824
# ICI Québec                             2525658
# Radio-Canada Sports                    2500095
# Le Nouvelliste                         2481513
# Radio-Canada Science                   2082819
# ICI Estrie                             1686238
# ICI Saguenay–Lac-Saint-Jean            1623999
# Le Téléjournal 18 h                    1430860
# Le Quotidien                           1362091
# La Tribune                             1254818
# Journal Métro                          1153067
# ...

# %%
fich[~medias].groupby(by=["Page Name"]).inter.sum().sort_values(ascending=False).head(50)
# Out:
# Page Name
# 45 minutes fois deux                       31943304
# Les annonces du foot                       28455266
# Piranha Club                               27986984
# Deli Cuisine                               27571548
# Sarra Messan                               23716068
# Barcelone FCB                              22897169
# Delucrece E                                16541791
# Mansour le Guisen                          13439395
# Mimiche Diabaté officiel                   12560730
# La Parole Vivante                          12312336
# Éric Duhaime                               11766890
# Justin Trudeau                             11684977
# Hayek Hassan                               11406103
# Le Magnific                                10772995
# Bara pro                                   10501533
# Commandant international224                 9692115
# Juste pour rire Les Gags                    9083482
# La parfaite maman cinglante                 8765370
# ...
